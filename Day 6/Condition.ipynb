# %%
# Conditions

# %%
x = 120
y = 150

if x > y:
  print('x is greather than y')
  print('Difference is ', x-y)
elif y > x :
  print('y is greater than x')
  print('Sum is ', x+y)
else:
  print('x and y are equal')
# Out:
# y is greater than x
# Sum is  270

# %%
a = int(input('Enter 1st number '))
b = int(input('Enter 2nd number '))

if a > b:
  print('a is greater than b')
  if a % 2 ==0 and a % 5==0:
    print('a is divisible by 2 and 5')
  else:
    print('a is not divisible by 2 and 5')
elif b > a:
  print('b is greater than a')
  if b % 3 ==0 or b % 7 ==0:
    print('b is divisible by 3 or 7')
  else:
    print('b is not divisible by 3 or 7')
else:
  print('a and b are equal')
# Out:
# Enter 1st number 10
# Enter 2nd number 15
# b is greater than a
# b is divisible by 3 or 7

# %%
num = float(input('Enter any number '))
if num % 2 == 0 and num % 5 == 0:
  print('Divisible by 2 and 5')
elif num % 2 ==0 and num % 5 != 0:
  print('No 1')
else:
  print('No 2')
# Out:
# Enter any number 8
# No 1

# %%
from IPython.display import Image
Image('Electricity.png')

# %%
amnt = 0
units = float(input('Enter units of electricity : '))

if units<=100:
  print('No Charge')
elif units >100 and units <=200:
  amnt = (units - 100) * 5
elif units >200 and units <=400:
  amnt = ((units - 200) * 10) +500
print('Amount is Rs ', amnt)
# Out:
# Enter units of electricity : 223
# Amount is Rs  730.0

# %%
Image('Assignment1.png')

# %%
# 1

length = float(input('Given length : '))
breadth = float(input('Given breadth : '))

if length == breadth:
  print('Square')
else:
  print('Not Square')
# Out:
# Given length : 12
# Given breadth : 12
# Square

# %%
# 2

num1 = int(input('Enter 1st number : '))
num2 = int(input('Enter 2nd number : '))
num3 = int(input('Enter 3rd number : ' ))

if num1 > num2 and num1 > num3:
  print(num1, ' is the largest number')
elif num2 > num1 and num2 > num3:
  print(num2, 'is the largest number')
else:
  print(num3, 'is the largest number')
# Out:
# Enter 1st number : 123
# Enter 2nd number : 3
# Enter 3rd number : 435
# 435 is the largest number

# %%
# 3

total_class = int(input('Enter total class : '))
attended_class = int(input('Enter attended class: '))

attendance = (attended_class/total_class) * 100

if attendance >= 75:
  print('Allowed and attendance is ', round (attendance, 2),'%')
else:
  print('Not Allowed and attendance is ', round (attendance, 2),'%')
# Out:
# Enter total class : 56
# Enter attended class: 53
# Allowed and attendance is  94.64 %

# %%
# 4

Image('Assignment1.png')

# %%
# 4

marks = int(input('Given marks 0 to 100 : '))

if marks >= 0 and marks <=100:
  if marks < 25:
    print('F')
  elif marks >= 25 and marks < 45:
    print('E')
  elif marks >= 45 and marks < 50:
    print('D')
  elif marks >= 50 and marks < 60:
    print('C')
  elif marks >= 60 and marks < 80:
    print('B')
  elif marks >= 80 and marks < 90:
    print('A')
  elif marks >=90:
    print('A+')
else:
  print('Given marks is invalid')
# Out:
# Given marks 0 to 100 : 43
# E
