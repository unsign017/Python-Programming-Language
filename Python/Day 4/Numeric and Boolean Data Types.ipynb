# %%
# Integers : This value is represented by integer class. It contains positive or negative whole numbers.
# Float : This value is represented by float class. It is real numbers with floating point representation.
# Complex : This value is represented by complex class. It is specified by (real part) + (Imiginary part)j.

# %%
x = 12
y = 13.5
z = 2+5j

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
a = int(y) # convert float to int

# %%
a
# Out:
# 13

# %%
b = float(x) # convert int to float

# %%
b
# Out:
# 12.0

# %%
c = complex(x) # convert int to complex

# %%
c
# Out:
# (12+0j)

# %%
d = complex(y) # convert float to complex

# %%
d
# Out:
# (13.5+0j)

# %%
e = int(z) # convert complex to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-160c51caba8a> in <cell line: 1>()
# ----> 1 e = int(z) # convert complex to int
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
f = float(z) # convert complex to float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ae91c1058e3b> in <cell line: 1>()
# ----> 1 f = float(z) # convert complex to float
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
isinstance(y, float)
# Out:
# True

# %%
isinstance(x, int)
# Out:
# True

# %%
isinstance(z, int)
# Out:
# False

# %%
isinstance(z, complex)
# Out:
# True

# %%
# Boolean Data types
# True : Boolean objects that are equal to true or truth
# False : Boolean objects that are equal to false.

# %%
m = True
n = False

# %%
m
# Out:
# True

# %%
n
# Out:
# False

# %%
type(m)
# Out:
# bool

# %%
type(n)
# Out:
# bool
